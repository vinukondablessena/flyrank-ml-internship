# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vinukondablessena/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# ## My Lane
#
# I selected **Lane 2 – Refresh / Content Opportunity Scoring**.
#
# I selected this lane because it focuses on identifying which content pages should be reviewed first. This project uses search performance and engagement data to prioritize content that may need updating. Since organizations have limited time and resources, ranking the most important pages first helps teams make better decisions. I chose this lane because it has practical business value and provides an opportunity to learn how machine learning can support content optimization.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
# ## Research Question
#
# **Research Question:**
# Which content pages should be reviewed first for refresh based on search performance and engagement signals?
#
# **Decision:**
# The decision is to identify which pages should receive priority for content review and improvement.
#
# **Action:**
# The content team can review the highest-ranked pages first and decide whether to refresh, expand, improve, monitor, or leave the page unchanged.
#
# **Cost of a Wrong Recommendation:**
# If the recommendation is incorrect, important pages may be overlooked while unnecessary effort is spent reviewing pages that do not actually need improvement. This wastes time and resources.
#
# **Why Machine Learning Helps:**
# The dataset contains many content pages with multiple performance indicators. Machine learning can analyze these patterns more efficiently than manual review and help produce a ranked list of pages for review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
# ## Quick Look at the Data
#
# ## Quick Look at the Data
#
# I loaded the starter dataset to understand whether this lane is suitable for further analysis.
#
# The dataset contains **30,000 rows** and **44 columns**, which means there is enough information to analyze content performance.
#
# The average **90-day impressions** is **5200.37**, showing that the dataset includes meaningful search performance data.
#
# These numbers indicate that the dataset is large enough and contains useful information for the **Refresh / Content Opportunity Scoring** lane.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/vinukondablessena/flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Total Rows:", len(df))
print("Total Columns:", len(df.columns))
print("Average 90-Day Impressions:", round(df["impressions_90d"].mean(), 2))
# Out:
# Total Rows: 30000
# Total Columns: 44
# Average 90-Day Impressions: 5200.37

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
# ## Quick Look at the Data
#
# ## Careful Words
#
# This project identifies patterns in the available search performance and engagement data. The results can help support decisions about which content pages should be reviewed first.
#
# However, this project cannot guarantee that refreshing a page will improve its search rankings or traffic. The recommendations are intended to support human decision-making based on observed data, not to predict Google's algorithms or prove cause and effect.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
